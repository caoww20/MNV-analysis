# %%
import os

# %%
### 012
cancerList = ["01.Breast","02.Prostate","03.Melanoma","04.Colon","05.Lung","06.Cervical","07.Uterine","08.Bladder","09.Rectal","10.Ovary","11.Kidney"]

for cancer in cancerList:
    fo = open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.geno.012.tsv","w")

    clinicDict = {}
    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.tsv","r") as fi:
        header = fi.readline().split()
        fo.write("\t".join(header+["MNVID","genotype"])+"\n")
        for line in fi:
            data = line.strip().split()
            clinicDict[data[0]] = data
    fi.close()

    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/04.SurvivalMNVsGenoData/"+cancer+"/survival.vcf","r") as fi:
        for line in fi:
            if line[:2] == "##":
                continue
            elif line[:4] == "#CHR":
                sampleIDList = line.strip().split()[9:]
            else:
                data = line.strip().split()
                genoData = data[9:]
                for i in range(len(sampleIDList)):
                    if sampleIDList[i] in clinicDict:
                        if genoData[i] == "0/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"0"])+"\n")
                        elif genoData[i] == "0/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"1"])+"\n")
                        elif genoData[i] == "1/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"1"])+"\n")
                        elif genoData[i] == "1/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"2"])+"\n")
                        else:
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"NA"])+"\n")
    fi.close()

# %%
### 02
cancerList = ["01.Breast","02.Prostate","03.Melanoma","04.Colon","05.Lung","06.Cervical","07.Uterine","08.Bladder","09.Rectal","10.Ovary","11.Kidney"]

for cancer in cancerList:
    fo = open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.geno.02.tsv","w")

    clinicDict = {}
    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.tsv","r") as fi:
        header = fi.readline().split()
        fo.write("\t".join(header+["MNVID","genotype"])+"\n")
        for line in fi:
            data = line.strip().split()
            clinicDict[data[0]] = data
    fi.close()

    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/04.SurvivalMNVsGenoData/"+cancer+"/survival.vcf","r") as fi:
        for line in fi:
            if line[:2] == "##":
                continue
            elif line[:4] == "#CHR":
                sampleIDList = line.strip().split()[9:]
            else:
                data = line.strip().split()
                genoData = data[9:]
                for i in range(len(sampleIDList)):
                    if sampleIDList[i] in clinicDict:
                        if genoData[i] == "0/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"0"])+"\n")
                        elif genoData[i] == "0/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"0"])+"\n")
                        elif genoData[i] == "1/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"0"])+"\n")
                        elif genoData[i] == "1/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"2"])+"\n")
                        else:
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"NA"])+"\n")
    fi.close()

# %%
### 01
cancerList = ["01.Breast","02.Prostate","03.Melanoma","04.Colon","05.Lung","06.Cervical","07.Uterine","08.Bladder","09.Rectal","10.Ovary","11.Kidney"]

for cancer in cancerList:
    fo = open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.geno.01.tsv","w")

    clinicDict = {}
    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/02.PhenoData/"+cancer+"/clinic.tsv","r") as fi:
        header = fi.readline().split()
        fo.write("\t".join(header+["MNVID","genotype"])+"\n")
        for line in fi:
            data = line.strip().split()
            clinicDict[data[0]] = data
    fi.close()

    with open("/home/luohh/MNVAnalysis/01.GWAS/02.Cancer/01.Data/04.SurvivalMNVsGenoData/"+cancer+"/survival.vcf","r") as fi:
        for line in fi:
            if line[:2] == "##":
                continue
            elif line[:4] == "#CHR":
                sampleIDList = line.strip().split()[9:]
            else:
                data = line.strip().split()
                genoData = data[9:]
                for i in range(len(sampleIDList)):
                    if sampleIDList[i] in clinicDict:
                        if genoData[i] == "0/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"0"])+"\n")
                        elif genoData[i] == "0/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"1"])+"\n")
                        elif genoData[i] == "1/0":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"1"])+"\n")
                        elif genoData[i] == "1/1":
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"1"])+"\n")
                        else:
                            fo.write("\t".join(clinicDict[sampleIDList[i]]+[data[2],"NA"])+"\n")
    fi.close()
